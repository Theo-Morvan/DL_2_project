# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets
import pandas as pd
import numpy as np
from src.vae_torch import *
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Definition des hyperparamètres pour l'entrainement

# %%
batch_size = 256
learning_rate = 0.005
middle_layer_size = 100
input_size = 28*28*1
latent_dim = 20
n_epochs = 100

# %% [markdown]
# # Entrainement et Résultats

# %% [markdown]
# ## VAE

# %%
model = VAE(input_size,middle_layer_size, latent_dim)

# %%
mnist_trainset = Dataset("c:\\Users\\32mor\\OneDrive\\Documents\\IPP M2\\DL2\\DL_2_project\\tristan\\data\\mnist_train.csv")
mnist_testset = Dataset("c:\\Users\\32mor\\OneDrive\\Documents\\IPP M2\\DL2\\DL_2_project\\tristan\\data\\mnist_test.csv")
mnist_train_loader = torch.utils.data.DataLoader(mnist_trainset, batch_size=batch_size, shuffle=True,
                                                    drop_last=True)
mnist_test_loader = torch.utils.data.DataLoader(mnist_testset, batch_size=batch_size, shuffle=True,
                                                    drop_last=True)

# %%
data, labels = next(iter(mnist_train_loader))

# %%
train_model(model, learning_rate, mnist_train_loader,batch_size, n_epochs)
# Out:
# [*] Epoch 0, average loss : 173.34210384114584
# [*] Epoch 1, average loss : 120.800484765625
# [*] Epoch 2, average loss : 110.37814899088542
# [*] Epoch 3, average loss : 105.878046875
# [*] Epoch 4, average loss : 103.20307268880208
# [*] Epoch 5, average loss : 101.36928134765625
# [*] Epoch 6, average loss : 100.07848564453126
# [*] Epoch 7, average loss : 99.16526666666667
# [*] Epoch 8, average loss : 98.57030823567709
# [*] Epoch 9, average loss : 97.88011162109375
# [*] Epoch 10, average loss : 97.27151097005208
# [*] Epoch 11, average loss : 96.86455377604166
# [*] Epoch 12, average loss : 96.49716787109375
# [*] Epoch 13, average loss : 96.07133616536458
# [*] Epoch 14, average loss : 95.79504329427084
# [*] Epoch 15, average loss : 95.5268326171875
# [*] Epoch 16, average loss : 95.22968818359375
# [*] Epoch 17, average loss : 95.07104680989583
# [*] Epoch 18, average loss : 94.79001513671875
# [*] Epoch 19, average loss : 94.75058030598959
# [*] Epoch 20, average loss : 94.54061041666667
# [*] Epoch 21, average loss : 94.38681175130208
# [*] Epoch 22, average loss : 94.32112047526041
# [*] Epoch 23, average loss : 94.22397571614583
# [*] Epoch 24, average loss : 94.14387057291667
# [*] Epoch 25, average loss : 93.94607454427083
# [*] Epoch 26, average loss : 93.810741796875
# [*] Epoch 27, average loss : 93.849401953125
# [*] Epoch 28, average loss : 93.6559341796875
# [*] Epoch 29, average loss : 93.62590250651041
# [*] Epoch 30, average loss : 93.52866656901041
# [*] Epoch 31, average loss : 93.36206985677083
# [*] Epoch 32, average loss : 93.31213707682292
# [*] Epoch 33, average loss : 93.36620244140624
# [*] Epoch 34, average loss : 93.2777859375
# [*] Epoch 35, average loss : 93.16520074869791
# [*] Epoch 36, average loss : 93.11191171875
# [*] Epoch 37, average loss : 93.00240367838542
# [*] Epoch 38, average loss : 92.91354124348959
# [*] Epoch 39, average loss : 93.06387115885417
# [*] Epoch 40, average loss : 93.00785738932292
# [*] Epoch 41, average loss : 92.77494547526042
# [*] Epoch 42, average loss : 92.818540625
# [*] Epoch 43, average loss : 92.68984514973958
# [*] Epoch 44, average loss : 92.68945657552084
# [*] Epoch 45, average loss : 92.67480983072916
# [*] Epoch 46, average loss : 92.53576048177084
# [*] Epoch 47, average loss : 92.5666814453125
# [*] Epoch 48, average loss : 92.46469449869792
# [*] Epoch 49, average loss : 92.40153606770834
# [*] Epoch 50, average loss : 92.57261647135417
# [*] Epoch 51, average loss : 92.36842307942709
# [*] Epoch 52, average loss : 92.33697845052083
# [*] Epoch 53, average loss : 92.34786656901042
# [*] Epoch 54, average loss : 92.34981927083334
# [*] Epoch 55, average loss : 92.30572610677083
# [*] Epoch 56, average loss : 92.22063899739584
# [*] Epoch 57, average loss : 92.14037571614584
# [*] Epoch 58, average loss : 92.1159595703125
# [*] Epoch 59, average loss : 92.14681666666667
# [*] Epoch 60, average loss : 92.1448974609375
# [*] Epoch 61, average loss : 92.06340286458334
# [*] Epoch 62, average loss : 92.02536240234375
# [*] Epoch 63, average loss : 92.10712734375
# [*] Epoch 64, average loss : 92.0595185546875
# [*] Epoch 65, average loss : 91.98572327473958
# [*] Epoch 66, average loss : 91.95268902994792
# [*] Epoch 67, average loss : 91.96855517578125
# [*] Epoch 68, average loss : 91.91385989583334
# [*] Epoch 69, average loss : 91.88061585286458
# [*] Epoch 70, average loss : 91.94514290364583
# [*] Epoch 71, average loss : 91.86007936197916
# [*] Epoch 72, average loss : 91.8248537109375
# [*] Epoch 73, average loss : 91.87723714192708
# [*] Epoch 74, average loss : 91.92528580729167
# [*] Epoch 75, average loss : 91.73058180338542
# [*] Epoch 76, average loss : 91.81032291666666
# [*] Epoch 77, average loss : 91.75227174479167
# [*] Epoch 78, average loss : 91.71647682291666
# [*] Epoch 79, average loss : 91.67878229166666
# [*] Epoch 80, average loss : 91.71595540364584
# [*] Epoch 81, average loss : 91.64246848958334
# [*] Epoch 82, average loss : 91.62969739583333
# [*] Epoch 83, average loss : 91.66370794270833
# [*] Epoch 84, average loss : 91.67567154947916
# [*] Epoch 85, average loss : 91.63767483723959
# [*] Epoch 86, average loss : 91.55372734375
# [*] Epoch 87, average loss : 91.69683268229167
# [*] Epoch 88, average loss : 91.47160716145834
# [*] Epoch 89, average loss : 91.569096484375
# [*] Epoch 90, average loss : 91.588294921875
# [*] Epoch 91, average loss : 91.54925520833334
# [*] Epoch 92, average loss : 91.53786354166667
# [*] Epoch 93, average loss : 91.49883014322917
# [*] Epoch 94, average loss : 91.38752447916667
# [*] Epoch 95, average loss : 91.52967884114584
# [*] Epoch 96, average loss : 91.3603072265625
# [*] Epoch 97, average loss : 91.60627639973958
# [*] Epoch 98, average loss : 91.48971370442709
# [*] Epoch 99, average loss : 91.4584865234375

# %%
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

# %%
images = generate_data(model, 5)
fig, axes = plt.subplots(1,5, figsize=(30,10))
for i in range(5):
    axes[i].imshow(images[i].view(28,28,1).detach().numpy())
    axes[i].set_xticks([])
    axes[i].set_yticks([])
plt.savefig("images_VAE_ADAM_higher_lr.png")

# %% [markdown]
# ## DBN

# %%
from src.dbn import DBN
from src.data import lire_mnist

X_train, y_train, X_test, y_test = lire_mnist("data/mnist_train.csv", "data/mnist_test.csv")
model = DBN([784, 150, 150])

# %%
model.train(X_train,0.01,batch_size , 100)
# Out:
# Epoch 0, erreur quadratique moyenne de reconstruction : 0.014968
# Epoch 1, erreur quadratique moyenne de reconstruction : 0.014959
# Epoch 2, erreur quadratique moyenne de reconstruction : 0.014953
# Epoch 3, erreur quadratique moyenne de reconstruction : 0.014948
# Epoch 4, erreur quadratique moyenne de reconstruction : 0.014947
# Epoch 5, erreur quadratique moyenne de reconstruction : 0.014946
# Epoch 6, erreur quadratique moyenne de reconstruction : 0.014943
# Epoch 7, erreur quadratique moyenne de reconstruction : 0.014935
# Epoch 8, erreur quadratique moyenne de reconstruction : 0.014935
# Epoch 9, erreur quadratique moyenne de reconstruction : 0.014934
# Epoch 10, erreur quadratique moyenne de reconstruction : 0.014932
# Epoch 11, erreur quadratique moyenne de reconstruction : 0.014932
# Epoch 12, erreur quadratique moyenne de reconstruction : 0.014927
# Epoch 13, erreur quadratique moyenne de reconstruction : 0.014921
# Epoch 14, erreur quadratique moyenne de reconstruction : 0.014920
# Epoch 15, erreur quadratique moyenne de reconstruction : 0.014917
# Epoch 16, erreur quadratique moyenne de reconstruction : 0.014913
# Epoch 17, erreur quadratique moyenne de reconstruction : 0.014917
# Epoch 18, erreur quadratique moyenne de reconstruction : 0.014913
# Epoch 19, erreur quadratique moyenne de reconstruction : 0.014911
# Epoch 20, erreur quadratique moyenne de reconstruction : 0.014909
# Epoch 21, erreur quadratique moyenne de reconstruction : 0.014907
# Epoch 22, erreur quadratique moyenne de reconstruction : 0.014905
# Epoch 23, erreur quadratique moyenne de reconstruction : 0.014903
# Epoch 24, erreur quadratique moyenne de reconstruction : 0.014905
# Epoch 25, erreur quadratique moyenne de reconstruction : 0.014902
# Epoch 26, erreur quadratique moyenne de reconstruction : 0.014900
# Epoch 27, erreur quadratique moyenne de reconstruction : 0.014898
# Epoch 28, erreur quadratique moyenne de reconstruction : 0.014896
# Epoch 29, erreur quadratique moyenne de reconstruction : 0.014896
# Epoch 30, erreur quadratique moyenne de reconstruction : 0.014894
# Epoch 31, erreur quadratique moyenne de reconstruction : 0.014890
# Epoch 32, erreur quadratique moyenne de reconstruction : 0.014889
# Epoch 33, erreur quadratique moyenne de reconstruction : 0.014889
# Epoch 34, erreur quadratique moyenne de reconstruction : 0.014885
# Epoch 35, erreur quadratique moyenne de reconstruction : 0.014886
# Epoch 36, erreur quadratique moyenne de reconstruction : 0.014884
# Epoch 37, erreur quadratique moyenne de reconstruction : 0.014883
# Epoch 38, erreur quadratique moyenne de reconstruction : 0.014881
# Epoch 39, erreur quadratique moyenne de reconstruction : 0.014878
# Epoch 40, erreur quadratique moyenne de reconstruction : 0.014876
# Epoch 41, erreur quadratique moyenne de reconstruction : 0.014877
# Epoch 42, erreur quadratique moyenne de reconstruction : 0.014874
# Epoch 43, erreur quadratique moyenne de reconstruction : 0.014873
# Epoch 44, erreur quadratique moyenne de reconstruction : 0.014868
# Epoch 45, erreur quadratique moyenne de reconstruction : 0.014868
# Epoch 46, erreur quadratique moyenne de reconstruction : 0.014863
# Epoch 47, erreur quadratique moyenne de reconstruction : 0.014861
# Epoch 48, erreur quadratique moyenne de reconstruction : 0.014865
# Epoch 49, erreur quadratique moyenne de reconstruction : 0.014862
# Epoch 50, erreur quadratique moyenne de reconstruction : 0.014863
# Epoch 51, erreur quadratique moyenne de reconstruction : 0.014861
# Epoch 52, erreur quadratique moyenne de reconstruction : 0.014857
# Epoch 53, erreur quadratique moyenne de reconstruction : 0.014859
# Epoch 54, erreur quadratique moyenne de reconstruction : 0.014855
# Epoch 55, erreur quadratique moyenne de reconstruction : 0.014853
# Epoch 56, erreur quadratique moyenne de reconstruction : 0.014851
# Epoch 57, erreur quadratique moyenne de reconstruction : 0.014849
# Epoch 58, erreur quadratique moyenne de reconstruction : 0.014850
# Epoch 59, erreur quadratique moyenne de reconstruction : 0.014847
# Epoch 60, erreur quadratique moyenne de reconstruction : 0.014844
# Epoch 61, erreur quadratique moyenne de reconstruction : 0.014842
# Epoch 62, erreur quadratique moyenne de reconstruction : 0.014840
# Epoch 63, erreur quadratique moyenne de reconstruction : 0.014840
# Epoch 64, erreur quadratique moyenne de reconstruction : 0.014837
# Epoch 65, erreur quadratique moyenne de reconstruction : 0.014837
# Epoch 66, erreur quadratique moyenne de reconstruction : 0.014834
# Epoch 67, erreur quadratique moyenne de reconstruction : 0.014835
# Epoch 68, erreur quadratique moyenne de reconstruction : 0.014832
# Epoch 69, erreur quadratique moyenne de reconstruction : 0.014834
# Epoch 70, erreur quadratique moyenne de reconstruction : 0.014831
# Epoch 71, erreur quadratique moyenne de reconstruction : 0.014825
# Epoch 72, erreur quadratique moyenne de reconstruction : 0.014827
# Epoch 73, erreur quadratique moyenne de reconstruction : 0.014826
# Epoch 74, erreur quadratique moyenne de reconstruction : 0.014827
# Epoch 75, erreur quadratique moyenne de reconstruction : 0.014826
# Epoch 76, erreur quadratique moyenne de reconstruction : 0.014821
# Epoch 77, erreur quadratique moyenne de reconstruction : 0.014822
# Epoch 78, erreur quadratique moyenne de reconstruction : 0.014819
# Epoch 79, erreur quadratique moyenne de reconstruction : 0.014818
# Epoch 80, erreur quadratique moyenne de reconstruction : 0.014818
# Epoch 81, erreur quadratique moyenne de reconstruction : 0.014817
# Epoch 82, erreur quadratique moyenne de reconstruction : 0.014811
# Epoch 83, erreur quadratique moyenne de reconstruction : 0.014812
# Epoch 84, erreur quadratique moyenne de reconstruction : 0.014808
# Epoch 85, erreur quadratique moyenne de reconstruction : 0.014804
# Epoch 86, erreur quadratique moyenne de reconstruction : 0.014803
# Epoch 87, erreur quadratique moyenne de reconstruction : 0.014804
# Epoch 88, erreur quadratique moyenne de reconstruction : 0.014805
# Epoch 89, erreur quadratique moyenne de reconstruction : 0.014801
# Epoch 90, erreur quadratique moyenne de reconstruction : 0.014801
# Epoch 91, erreur quadratique moyenne de reconstruction : 0.014797
# Epoch 92, erreur quadratique moyenne de reconstruction : 0.014792
# Epoch 93, erreur quadratique moyenne de reconstruction : 0.014794
# Epoch 94, erreur quadratique moyenne de reconstruction : 0.014792
# Epoch 95, erreur quadratique moyenne de reconstruction : 0.014793
# Epoch 96, erreur quadratique moyenne de reconstruction : 0.014790
# Epoch 97, erreur quadratique moyenne de reconstruction : 0.014791
# Epoch 98, erreur quadratique moyenne de reconstruction : 0.014785
# Epoch 99, erreur quadratique moyenne de reconstruction : 0.014785
# Epoch 0, erreur quadratique moyenne de reconstruction : 0.019591
# Epoch 1, erreur quadratique moyenne de reconstruction : 0.019533
# Epoch 2, erreur quadratique moyenne de reconstruction : 0.019504
# Epoch 3, erreur quadratique moyenne de reconstruction : 0.019478
# Epoch 4, erreur quadratique moyenne de reconstruction : 0.019470
# Epoch 5, erreur quadratique moyenne de reconstruction : 0.019452
# Epoch 6, erreur quadratique moyenne de reconstruction : 0.019444
# Epoch 7, erreur quadratique moyenne de reconstruction : 0.019416
# Epoch 8, erreur quadratique moyenne de reconstruction : 0.019415
# Epoch 9, erreur quadratique moyenne de reconstruction : 0.019396
# Epoch 10, erreur quadratique moyenne de reconstruction : 0.019395
# Epoch 11, erreur quadratique moyenne de reconstruction : 0.019395
# Epoch 12, erreur quadratique moyenne de reconstruction : 0.019376
# Epoch 13, erreur quadratique moyenne de reconstruction : 0.019365
# Epoch 14, erreur quadratique moyenne de reconstruction : 0.019363
# Epoch 15, erreur quadratique moyenne de reconstruction : 0.019354
# Epoch 16, erreur quadratique moyenne de reconstruction : 0.019359
# Epoch 17, erreur quadratique moyenne de reconstruction : 0.019347
# Epoch 18, erreur quadratique moyenne de reconstruction : 0.019345
# Epoch 19, erreur quadratique moyenne de reconstruction : 0.019339
# Epoch 20, erreur quadratique moyenne de reconstruction : 0.019333
# Epoch 21, erreur quadratique moyenne de reconstruction : 0.019328
# Epoch 22, erreur quadratique moyenne de reconstruction : 0.019332
# Epoch 23, erreur quadratique moyenne de reconstruction : 0.019308
# Epoch 24, erreur quadratique moyenne de reconstruction : 0.019298
# Epoch 25, erreur quadratique moyenne de reconstruction : 0.019297
# Epoch 26, erreur quadratique moyenne de reconstruction : 0.019297
# Epoch 27, erreur quadratique moyenne de reconstruction : 0.019299
# Epoch 28, erreur quadratique moyenne de reconstruction : 0.019291
# Epoch 29, erreur quadratique moyenne de reconstruction : 0.019278
# Epoch 30, erreur quadratique moyenne de reconstruction : 0.019283
# Epoch 31, erreur quadratique moyenne de reconstruction : 0.019288
# Epoch 32, erreur quadratique moyenne de reconstruction : 0.019276
# Epoch 33, erreur quadratique moyenne de reconstruction : 0.019271
# Epoch 34, erreur quadratique moyenne de reconstruction : 0.019266
# Epoch 35, erreur quadratique moyenne de reconstruction : 0.019263
# Epoch 36, erreur quadratique moyenne de reconstruction : 0.019263
# Epoch 37, erreur quadratique moyenne de reconstruction : 0.019267
# Epoch 38, erreur quadratique moyenne de reconstruction : 0.019252
# Epoch 39, erreur quadratique moyenne de reconstruction : 0.019243
# Epoch 40, erreur quadratique moyenne de reconstruction : 0.019240
# Epoch 41, erreur quadratique moyenne de reconstruction : 0.019235
# Epoch 42, erreur quadratique moyenne de reconstruction : 0.019232
# Epoch 43, erreur quadratique moyenne de reconstruction : 0.019228
# Epoch 44, erreur quadratique moyenne de reconstruction : 0.019215
# Epoch 45, erreur quadratique moyenne de reconstruction : 0.019219
# Epoch 46, erreur quadratique moyenne de reconstruction : 0.019213
# Epoch 47, erreur quadratique moyenne de reconstruction : 0.019217
# Epoch 48, erreur quadratique moyenne de reconstruction : 0.019203
# Epoch 49, erreur quadratique moyenne de reconstruction : 0.019199
# Epoch 50, erreur quadratique moyenne de reconstruction : 0.019193
# Epoch 51, erreur quadratique moyenne de reconstruction : 0.019187
# Epoch 52, erreur quadratique moyenne de reconstruction : 0.019200
# Epoch 53, erreur quadratique moyenne de reconstruction : 0.019208
# Epoch 54, erreur quadratique moyenne de reconstruction : 0.019196
# Epoch 55, erreur quadratique moyenne de reconstruction : 0.019179
# Epoch 56, erreur quadratique moyenne de reconstruction : 0.019176
# Epoch 57, erreur quadratique moyenne de reconstruction : 0.019158
# Epoch 58, erreur quadratique moyenne de reconstruction : 0.019153
# Epoch 59, erreur quadratique moyenne de reconstruction : 0.019159
# Epoch 60, erreur quadratique moyenne de reconstruction : 0.019147
# Epoch 61, erreur quadratique moyenne de reconstruction : 0.019152
# Epoch 62, erreur quadratique moyenne de reconstruction : 0.019147
# Epoch 63, erreur quadratique moyenne de reconstruction : 0.019168
# Epoch 64, erreur quadratique moyenne de reconstruction : 0.019146
# Epoch 65, erreur quadratique moyenne de reconstruction : 0.019150
# Epoch 66, erreur quadratique moyenne de reconstruction : 0.019126
# Epoch 67, erreur quadratique moyenne de reconstruction : 0.019135
# Epoch 68, erreur quadratique moyenne de reconstruction : 0.019131
# Epoch 69, erreur quadratique moyenne de reconstruction : 0.019117
# Epoch 70, erreur quadratique moyenne de reconstruction : 0.019127
# Epoch 71, erreur quadratique moyenne de reconstruction : 0.019135
# Epoch 72, erreur quadratique moyenne de reconstruction : 0.019131
# Epoch 73, erreur quadratique moyenne de reconstruction : 0.019129
# Epoch 74, erreur quadratique moyenne de reconstruction : 0.019126
# Epoch 75, erreur quadratique moyenne de reconstruction : 0.019119
# Epoch 76, erreur quadratique moyenne de reconstruction : 0.019111
# Epoch 77, erreur quadratique moyenne de reconstruction : 0.019105
# Epoch 78, erreur quadratique moyenne de reconstruction : 0.019103
# Epoch 79, erreur quadratique moyenne de reconstruction : 0.019106
# Epoch 80, erreur quadratique moyenne de reconstruction : 0.019101
# Epoch 81, erreur quadratique moyenne de reconstruction : 0.019099
# Epoch 82, erreur quadratique moyenne de reconstruction : 0.019087
# Epoch 83, erreur quadratique moyenne de reconstruction : 0.019087
# Epoch 84, erreur quadratique moyenne de reconstruction : 0.019082
# Epoch 85, erreur quadratique moyenne de reconstruction : 0.019078
# Epoch 86, erreur quadratique moyenne de reconstruction : 0.019073
# Epoch 87, erreur quadratique moyenne de reconstruction : 0.019079
# Epoch 88, erreur quadratique moyenne de reconstruction : 0.019081
# Epoch 89, erreur quadratique moyenne de reconstruction : 0.019077
# Epoch 90, erreur quadratique moyenne de reconstruction : 0.019072
# Epoch 91, erreur quadratique moyenne de reconstruction : 0.019056
# Epoch 92, erreur quadratique moyenne de reconstruction : 0.019057
# Epoch 93, erreur quadratique moyenne de reconstruction : 0.019055
# Epoch 94, erreur quadratique moyenne de reconstruction : 0.019059
# Epoch 95, erreur quadratique moyenne de reconstruction : 0.019047
# Epoch 96, erreur quadratique moyenne de reconstruction : 0.019060
# Epoch 97, erreur quadratique moyenne de reconstruction : 0.019042
# Epoch 98, erreur quadratique moyenne de reconstruction : 0.019040
# Epoch 99, erreur quadratique moyenne de reconstruction : 0.019048

# %%
images_dbn = model.generer_image(30, 10)
fig, axes = plt.subplots(1,5, figsize=(30,10))
for i in range(5):
    axes[i].imshow(images_dbn[i].reshape(28,28,1), cmap='gray')
plt.savefig("dbn_mnist_images_high_lr.png")

# %% [markdown]
# ## RBM

# %%
from src.rbm import RBM
from src.data import lire_alpha_digits
from src.utils import display_alpha_digits

# %%
rbm_mnist = RBM(784,200)

# %%
rbm_mnist.train(X_train,learning_rate, batch_size, n_epochs)
# Out:
# Epoch 0, erreur quadratique moyenne de reconstruction : 0.087530
# Epoch 1, erreur quadratique moyenne de reconstruction : 0.082048
# Epoch 2, erreur quadratique moyenne de reconstruction : 0.074179
# Epoch 3, erreur quadratique moyenne de reconstruction : 0.067840
# Epoch 4, erreur quadratique moyenne de reconstruction : 0.063535
# Epoch 5, erreur quadratique moyenne de reconstruction : 0.060558
# Epoch 6, erreur quadratique moyenne de reconstruction : 0.058210
# Epoch 7, erreur quadratique moyenne de reconstruction : 0.056376
# Epoch 8, erreur quadratique moyenne de reconstruction : 0.054810
# Epoch 9, erreur quadratique moyenne de reconstruction : 0.053351
# Epoch 10, erreur quadratique moyenne de reconstruction : 0.052006
# Epoch 11, erreur quadratique moyenne de reconstruction : 0.050795
# Epoch 12, erreur quadratique moyenne de reconstruction : 0.049725
# Epoch 13, erreur quadratique moyenne de reconstruction : 0.048737
# Epoch 14, erreur quadratique moyenne de reconstruction : 0.047814
# Epoch 15, erreur quadratique moyenne de reconstruction : 0.046942
# Epoch 16, erreur quadratique moyenne de reconstruction : 0.046123
# Epoch 17, erreur quadratique moyenne de reconstruction : 0.045330
# Epoch 18, erreur quadratique moyenne de reconstruction : 0.044589
# Epoch 19, erreur quadratique moyenne de reconstruction : 0.043885
# Epoch 20, erreur quadratique moyenne de reconstruction : 0.043211
# Epoch 21, erreur quadratique moyenne de reconstruction : 0.042579
# Epoch 22, erreur quadratique moyenne de reconstruction : 0.041977
# Epoch 23, erreur quadratique moyenne de reconstruction : 0.041407
# Epoch 24, erreur quadratique moyenne de reconstruction : 0.040861
# Epoch 25, erreur quadratique moyenne de reconstruction : 0.040344
# Epoch 26, erreur quadratique moyenne de reconstruction : 0.039854
# Epoch 27, erreur quadratique moyenne de reconstruction : 0.039383
# Epoch 28, erreur quadratique moyenne de reconstruction : 0.038940
# Epoch 29, erreur quadratique moyenne de reconstruction : 0.038519
# Epoch 30, erreur quadratique moyenne de reconstruction : 0.038113
# Epoch 31, erreur quadratique moyenne de reconstruction : 0.037721
# Epoch 32, erreur quadratique moyenne de reconstruction : 0.037344
# Epoch 33, erreur quadratique moyenne de reconstruction : 0.036988
# Epoch 34, erreur quadratique moyenne de reconstruction : 0.036633
# Epoch 35, erreur quadratique moyenne de reconstruction : 0.036301
# Epoch 36, erreur quadratique moyenne de reconstruction : 0.035980
# Epoch 37, erreur quadratique moyenne de reconstruction : 0.035669
# Epoch 38, erreur quadratique moyenne de reconstruction : 0.035366
# Epoch 39, erreur quadratique moyenne de reconstruction : 0.035078
# Epoch 40, erreur quadratique moyenne de reconstruction : 0.034796
# Epoch 41, erreur quadratique moyenne de reconstruction : 0.034526
# Epoch 42, erreur quadratique moyenne de reconstruction : 0.034260
# Epoch 43, erreur quadratique moyenne de reconstruction : 0.034007
# Epoch 44, erreur quadratique moyenne de reconstruction : 0.033759
# Epoch 45, erreur quadratique moyenne de reconstruction : 0.033520
# Epoch 46, erreur quadratique moyenne de reconstruction : 0.033283
# Epoch 47, erreur quadratique moyenne de reconstruction : 0.033054
# Epoch 48, erreur quadratique moyenne de reconstruction : 0.032830
# Epoch 49, erreur quadratique moyenne de reconstruction : 0.032621
# Epoch 50, erreur quadratique moyenne de reconstruction : 0.032412
# Epoch 51, erreur quadratique moyenne de reconstruction : 0.032209
# Epoch 52, erreur quadratique moyenne de reconstruction : 0.032011
# Epoch 53, erreur quadratique moyenne de reconstruction : 0.031819
# Epoch 54, erreur quadratique moyenne de reconstruction : 0.031631
# Epoch 55, erreur quadratique moyenne de reconstruction : 0.031446
# Epoch 56, erreur quadratique moyenne de reconstruction : 0.031267
# Epoch 57, erreur quadratique moyenne de reconstruction : 0.031092
# Epoch 58, erreur quadratique moyenne de reconstruction : 0.030919
# Epoch 59, erreur quadratique moyenne de reconstruction : 0.030755
# Epoch 60, erreur quadratique moyenne de reconstruction : 0.030585
# Epoch 61, erreur quadratique moyenne de reconstruction : 0.030426
# Epoch 62, erreur quadratique moyenne de reconstruction : 0.030267
# Epoch 63, erreur quadratique moyenne de reconstruction : 0.030118
# Epoch 64, erreur quadratique moyenne de reconstruction : 0.029963
# Epoch 65, erreur quadratique moyenne de reconstruction : 0.029816
# Epoch 66, erreur quadratique moyenne de reconstruction : 0.029673
# Epoch 67, erreur quadratique moyenne de reconstruction : 0.029532
# Epoch 68, erreur quadratique moyenne de reconstruction : 0.029394
# Epoch 69, erreur quadratique moyenne de reconstruction : 0.029254
# Epoch 70, erreur quadratique moyenne de reconstruction : 0.029124
# Epoch 71, erreur quadratique moyenne de reconstruction : 0.028989
# Epoch 72, erreur quadratique moyenne de reconstruction : 0.028858
# Epoch 73, erreur quadratique moyenne de reconstruction : 0.028731
# Epoch 74, erreur quadratique moyenne de reconstruction : 0.028605
# Epoch 75, erreur quadratique moyenne de reconstruction : 0.028485
# Epoch 76, erreur quadratique moyenne de reconstruction : 0.028364
# Epoch 77, erreur quadratique moyenne de reconstruction : 0.028244
# Epoch 78, erreur quadratique moyenne de reconstruction : 0.028131
# Epoch 79, erreur quadratique moyenne de reconstruction : 0.028013
# Epoch 80, erreur quadratique moyenne de reconstruction : 0.027901
# Epoch 81, erreur quadratique moyenne de reconstruction : 0.027788
# Epoch 82, erreur quadratique moyenne de reconstruction : 0.027682
# Epoch 83, erreur quadratique moyenne de reconstruction : 0.027578
# Epoch 84, erreur quadratique moyenne de reconstruction : 0.027467
# Epoch 85, erreur quadratique moyenne de reconstruction : 0.027364
# Epoch 86, erreur quadratique moyenne de reconstruction : 0.027264
# Epoch 87, erreur quadratique moyenne de reconstruction : 0.027163
# Epoch 88, erreur quadratique moyenne de reconstruction : 0.027057
# Epoch 89, erreur quadratique moyenne de reconstruction : 0.026965
# Epoch 90, erreur quadratique moyenne de reconstruction : 0.026869
# Epoch 91, erreur quadratique moyenne de reconstruction : 0.026775
# Epoch 92, erreur quadratique moyenne de reconstruction : 0.026685
# Epoch 93, erreur quadratique moyenne de reconstruction : 0.026593
# Epoch 94, erreur quadratique moyenne de reconstruction : 0.026499
# Epoch 95, erreur quadratique moyenne de reconstruction : 0.026411
# Epoch 96, erreur quadratique moyenne de reconstruction : 0.026324
# Epoch 97, erreur quadratique moyenne de reconstruction : 0.026236
# Epoch 98, erreur quadratique moyenne de reconstruction : 0.026151
# Epoch 99, erreur quadratique moyenne de reconstruction : 0.026065

# %%
images_rbm = rbm_mnist.generer_image(10, 5)
fig, axes = plt.subplots(1,5, figsize=(30,10))
for i in range(5):
    axes[i].imshow(images_rbm[i].reshape(28,28,1),cmap="gray")
plt.savefig("images_rbm_mnist.png")

# %%
dbn_mnist = DBN([784,150, 150])
dbn_mnist.train(X_train, learning_rate, batch_size, n_epochs)
# Out:
# Epoch 0, erreur quadratique moyenne de reconstruction : 0.084122
# Epoch 1, erreur quadratique moyenne de reconstruction : 0.069620
# Epoch 2, erreur quadratique moyenne de reconstruction : 0.062581
# Epoch 3, erreur quadratique moyenne de reconstruction : 0.058296
# Epoch 4, erreur quadratique moyenne de reconstruction : 0.055450
# Epoch 5, erreur quadratique moyenne de reconstruction : 0.053049
# Epoch 6, erreur quadratique moyenne de reconstruction : 0.050925
# Epoch 7, erreur quadratique moyenne de reconstruction : 0.049161
# Epoch 8, erreur quadratique moyenne de reconstruction : 0.047611
# Epoch 9, erreur quadratique moyenne de reconstruction : 0.046238
# Epoch 10, erreur quadratique moyenne de reconstruction : 0.045002
# Epoch 11, erreur quadratique moyenne de reconstruction : 0.043866
# Epoch 12, erreur quadratique moyenne de reconstruction : 0.042852
# Epoch 13, erreur quadratique moyenne de reconstruction : 0.041922
# Epoch 14, erreur quadratique moyenne de reconstruction : 0.041055
# Epoch 15, erreur quadratique moyenne de reconstruction : 0.040268
# Epoch 16, erreur quadratique moyenne de reconstruction : 0.039540
# Epoch 17, erreur quadratique moyenne de reconstruction : 0.038842
# Epoch 18, erreur quadratique moyenne de reconstruction : 0.038216
# Epoch 19, erreur quadratique moyenne de reconstruction : 0.037621
# Epoch 20, erreur quadratique moyenne de reconstruction : 0.037063
# Epoch 21, erreur quadratique moyenne de reconstruction : 0.036543
# Epoch 22, erreur quadratique moyenne de reconstruction : 0.036055
# Epoch 23, erreur quadratique moyenne de reconstruction : 0.035595
# Epoch 24, erreur quadratique moyenne de reconstruction : 0.035160
# Epoch 25, erreur quadratique moyenne de reconstruction : 0.034750
# Epoch 26, erreur quadratique moyenne de reconstruction : 0.034351
# Epoch 27, erreur quadratique moyenne de reconstruction : 0.033979
# Epoch 28, erreur quadratique moyenne de reconstruction : 0.033628
# Epoch 29, erreur quadratique moyenne de reconstruction : 0.033293
# Epoch 30, erreur quadratique moyenne de reconstruction : 0.032973
# Epoch 31, erreur quadratique moyenne de reconstruction : 0.032664
# Epoch 32, erreur quadratique moyenne de reconstruction : 0.032378
# Epoch 33, erreur quadratique moyenne de reconstruction : 0.032100
# Epoch 34, erreur quadratique moyenne de reconstruction : 0.031837
# Epoch 35, erreur quadratique moyenne de reconstruction : 0.031570
# Epoch 36, erreur quadratique moyenne de reconstruction : 0.031325
# Epoch 37, erreur quadratique moyenne de reconstruction : 0.031090
# Epoch 38, erreur quadratique moyenne de reconstruction : 0.030867
# Epoch 39, erreur quadratique moyenne de reconstruction : 0.030634
# Epoch 40, erreur quadratique moyenne de reconstruction : 0.030422
# Epoch 41, erreur quadratique moyenne de reconstruction : 0.030223
# Epoch 42, erreur quadratique moyenne de reconstruction : 0.030015
# Epoch 43, erreur quadratique moyenne de reconstruction : 0.029826
# Epoch 44, erreur quadratique moyenne de reconstruction : 0.029633
# Epoch 45, erreur quadratique moyenne de reconstruction : 0.029451
# Epoch 46, erreur quadratique moyenne de reconstruction : 0.029274
# Epoch 47, erreur quadratique moyenne de reconstruction : 0.029104
# Epoch 48, erreur quadratique moyenne de reconstruction : 0.028934
# Epoch 49, erreur quadratique moyenne de reconstruction : 0.028774
# Epoch 50, erreur quadratique moyenne de reconstruction : 0.028614
# Epoch 51, erreur quadratique moyenne de reconstruction : 0.028463
# Epoch 52, erreur quadratique moyenne de reconstruction : 0.028316
# Epoch 53, erreur quadratique moyenne de reconstruction : 0.028160
# Epoch 54, erreur quadratique moyenne de reconstruction : 0.028026
# Epoch 55, erreur quadratique moyenne de reconstruction : 0.027884
# Epoch 56, erreur quadratique moyenne de reconstruction : 0.027748
# Epoch 57, erreur quadratique moyenne de reconstruction : 0.027617
# Epoch 58, erreur quadratique moyenne de reconstruction : 0.027488
# Epoch 59, erreur quadratique moyenne de reconstruction : 0.027360
# Epoch 60, erreur quadratique moyenne de reconstruction : 0.027235
# Epoch 61, erreur quadratique moyenne de reconstruction : 0.027114
# Epoch 62, erreur quadratique moyenne de reconstruction : 0.026998
# Epoch 63, erreur quadratique moyenne de reconstruction : 0.026880
# Epoch 64, erreur quadratique moyenne de reconstruction : 0.026769
# Epoch 65, erreur quadratique moyenne de reconstruction : 0.026659
# Epoch 66, erreur quadratique moyenne de reconstruction : 0.026547
# Epoch 67, erreur quadratique moyenne de reconstruction : 0.026442
# Epoch 68, erreur quadratique moyenne de reconstruction : 0.026332
# Epoch 69, erreur quadratique moyenne de reconstruction : 0.026239
# Epoch 70, erreur quadratique moyenne de reconstruction : 0.026134
# Epoch 71, erreur quadratique moyenne de reconstruction : 0.026037
# Epoch 72, erreur quadratique moyenne de reconstruction : 0.025937
# Epoch 73, erreur quadratique moyenne de reconstruction : 0.025842
# Epoch 74, erreur quadratique moyenne de reconstruction : 0.025750
# Epoch 75, erreur quadratique moyenne de reconstruction : 0.025658
# Epoch 76, erreur quadratique moyenne de reconstruction : 0.025567
# Epoch 77, erreur quadratique moyenne de reconstruction : 0.025484
# Epoch 78, erreur quadratique moyenne de reconstruction : 0.025395
# Epoch 79, erreur quadratique moyenne de reconstruction : 0.025307
# Epoch 80, erreur quadratique moyenne de reconstruction : 0.025226
# Epoch 81, erreur quadratique moyenne de reconstruction : 0.025143
# Epoch 82, erreur quadratique moyenne de reconstruction : 0.025064
# Epoch 83, erreur quadratique moyenne de reconstruction : 0.024986
# Epoch 84, erreur quadratique moyenne de reconstruction : 0.024902
# Epoch 85, erreur quadratique moyenne de reconstruction : 0.024836
# Epoch 86, erreur quadratique moyenne de reconstruction : 0.024751
# Epoch 87, erreur quadratique moyenne de reconstruction : 0.024679
# Epoch 88, erreur quadratique moyenne de reconstruction : 0.024600
# Epoch 89, erreur quadratique moyenne de reconstruction : 0.024529
# Epoch 90, erreur quadratique moyenne de reconstruction : 0.024456
# Epoch 91, erreur quadratique moyenne de reconstruction : 0.024388
# Epoch 92, erreur quadratique moyenne de reconstruction : 0.024318
# Epoch 93, erreur quadratique moyenne de reconstruction : 0.024247
# Epoch 94, erreur quadratique moyenne de reconstruction : 0.024182
# Epoch 95, erreur quadratique moyenne de reconstruction : 0.024119
# Epoch 96, erreur quadratique moyenne de reconstruction : 0.024054
# Epoch 97, erreur quadratique moyenne de reconstruction : 0.023991
# Epoch 98, erreur quadratique moyenne de reconstruction : 0.023918
# Epoch 99, erreur quadratique moyenne de reconstruction : 0.023861
# Epoch 0, erreur quadratique moyenne de reconstruction : 0.172268
# Epoch 1, erreur quadratique moyenne de reconstruction : 0.158806
# Epoch 2, erreur quadratique moyenne de reconstruction : 0.137631
# Epoch 3, erreur quadratique moyenne de reconstruction : 0.122838
# Epoch 4, erreur quadratique moyenne de reconstruction : 0.111452
# Epoch 5, erreur quadratique moyenne de reconstruction : 0.102918
# Epoch 6, erreur quadratique moyenne de reconstruction : 0.096605
# Epoch 7, erreur quadratique moyenne de reconstruction : 0.091849
# Epoch 8, erreur quadratique moyenne de reconstruction : 0.087766
# Epoch 9, erreur quadratique moyenne de reconstruction : 0.083861
# Epoch 10, erreur quadratique moyenne de reconstruction : 0.079989
# Epoch 11, erreur quadratique moyenne de reconstruction : 0.076372
# Epoch 12, erreur quadratique moyenne de reconstruction : 0.073082
# Epoch 13, erreur quadratique moyenne de reconstruction : 0.070177
# Epoch 14, erreur quadratique moyenne de reconstruction : 0.067608
# Epoch 15, erreur quadratique moyenne de reconstruction : 0.065317
# Epoch 16, erreur quadratique moyenne de reconstruction : 0.063166
# Epoch 17, erreur quadratique moyenne de reconstruction : 0.061194
# Epoch 18, erreur quadratique moyenne de reconstruction : 0.059371
# Epoch 19, erreur quadratique moyenne de reconstruction : 0.057683
# Epoch 20, erreur quadratique moyenne de reconstruction : 0.056045
# Epoch 21, erreur quadratique moyenne de reconstruction : 0.054514
# Epoch 22, erreur quadratique moyenne de reconstruction : 0.053083
# Epoch 23, erreur quadratique moyenne de reconstruction : 0.051729
# Epoch 24, erreur quadratique moyenne de reconstruction : 0.050417
# Epoch 25, erreur quadratique moyenne de reconstruction : 0.049214
# Epoch 26, erreur quadratique moyenne de reconstruction : 0.048052
# Epoch 27, erreur quadratique moyenne de reconstruction : 0.046956
# Epoch 28, erreur quadratique moyenne de reconstruction : 0.045930
# Epoch 29, erreur quadratique moyenne de reconstruction : 0.044958
# Epoch 30, erreur quadratique moyenne de reconstruction : 0.044033
# Epoch 31, erreur quadratique moyenne de reconstruction : 0.043126
# Epoch 32, erreur quadratique moyenne de reconstruction : 0.042282
# Epoch 33, erreur quadratique moyenne de reconstruction : 0.041513
# Epoch 34, erreur quadratique moyenne de reconstruction : 0.040732
# Epoch 35, erreur quadratique moyenne de reconstruction : 0.040002
# Epoch 36, erreur quadratique moyenne de reconstruction : 0.039314
# Epoch 37, erreur quadratique moyenne de reconstruction : 0.038676
# Epoch 38, erreur quadratique moyenne de reconstruction : 0.038012
# Epoch 39, erreur quadratique moyenne de reconstruction : 0.037377
# Epoch 40, erreur quadratique moyenne de reconstruction : 0.036791
# Epoch 41, erreur quadratique moyenne de reconstruction : 0.036235
# Epoch 42, erreur quadratique moyenne de reconstruction : 0.035672
# Epoch 43, erreur quadratique moyenne de reconstruction : 0.035122
# Epoch 44, erreur quadratique moyenne de reconstruction : 0.034619
# Epoch 45, erreur quadratique moyenne de reconstruction : 0.034130
# Epoch 46, erreur quadratique moyenne de reconstruction : 0.033643
# Epoch 47, erreur quadratique moyenne de reconstruction : 0.033185
# Epoch 48, erreur quadratique moyenne de reconstruction : 0.032723
# Epoch 49, erreur quadratique moyenne de reconstruction : 0.032314
# Epoch 50, erreur quadratique moyenne de reconstruction : 0.031875
# Epoch 51, erreur quadratique moyenne de reconstruction : 0.031474
# Epoch 52, erreur quadratique moyenne de reconstruction : 0.031085
# Epoch 53, erreur quadratique moyenne de reconstruction : 0.030701
# Epoch 54, erreur quadratique moyenne de reconstruction : 0.030328
# Epoch 55, erreur quadratique moyenne de reconstruction : 0.029979
# Epoch 56, erreur quadratique moyenne de reconstruction : 0.029653
# Epoch 57, erreur quadratique moyenne de reconstruction : 0.029315
# Epoch 58, erreur quadratique moyenne de reconstruction : 0.028990
# Epoch 59, erreur quadratique moyenne de reconstruction : 0.028658
# Epoch 60, erreur quadratique moyenne de reconstruction : 0.028360
# Epoch 61, erreur quadratique moyenne de reconstruction : 0.028082
# Epoch 62, erreur quadratique moyenne de reconstruction : 0.027764
# Epoch 63, erreur quadratique moyenne de reconstruction : 0.027544
# Epoch 64, erreur quadratique moyenne de reconstruction : 0.027274
# Epoch 65, erreur quadratique moyenne de reconstruction : 0.027000
# Epoch 66, erreur quadratique moyenne de reconstruction : 0.026751
# Epoch 67, erreur quadratique moyenne de reconstruction : 0.026507
# Epoch 68, erreur quadratique moyenne de reconstruction : 0.026290
# Epoch 69, erreur quadratique moyenne de reconstruction : 0.026058
# Epoch 70, erreur quadratique moyenne de reconstruction : 0.025858
# Epoch 71, erreur quadratique moyenne de reconstruction : 0.025644
# Epoch 72, erreur quadratique moyenne de reconstruction : 0.025410
# Epoch 73, erreur quadratique moyenne de reconstruction : 0.025210
# Epoch 74, erreur quadratique moyenne de reconstruction : 0.025031
# Epoch 75, erreur quadratique moyenne de reconstruction : 0.024843
# Epoch 76, erreur quadratique moyenne de reconstruction : 0.024653
# Epoch 77, erreur quadratique moyenne de reconstruction : 0.024488
# Epoch 78, erreur quadratique moyenne de reconstruction : 0.024299
# Epoch 79, erreur quadratique moyenne de reconstruction : 0.024114
# Epoch 80, erreur quadratique moyenne de reconstruction : 0.023955
# Epoch 81, erreur quadratique moyenne de reconstruction : 0.023808
# Epoch 82, erreur quadratique moyenne de reconstruction : 0.023635
# Epoch 83, erreur quadratique moyenne de reconstruction : 0.023494
# Epoch 84, erreur quadratique moyenne de reconstruction : 0.023346
# Epoch 85, erreur quadratique moyenne de reconstruction : 0.023208
# Epoch 86, erreur quadratique moyenne de reconstruction : 0.023041
# Epoch 87, erreur quadratique moyenne de reconstruction : 0.022918
# Epoch 88, erreur quadratique moyenne de reconstruction : 0.022776
# Epoch 89, erreur quadratique moyenne de reconstruction : 0.022653
# Epoch 90, erreur quadratique moyenne de reconstruction : 0.022519
# Epoch 91, erreur quadratique moyenne de reconstruction : 0.022382
# Epoch 92, erreur quadratique moyenne de reconstruction : 0.022263
# Epoch 93, erreur quadratique moyenne de reconstruction : 0.022163
# Epoch 94, erreur quadratique moyenne de reconstruction : 0.022035
# Epoch 95, erreur quadratique moyenne de reconstruction : 0.021907
# Epoch 96, erreur quadratique moyenne de reconstruction : 0.021810
# Epoch 97, erreur quadratique moyenne de reconstruction : 0.021695
# Epoch 98, erreur quadratique moyenne de reconstruction : 0.021585
# Epoch 99, erreur quadratique moyenne de reconstruction : 0.021476

# %%
images_dbn = dbn_mnist.generer_image(30, 10)

# %%
fig, axes = plt.subplots(1,5, figsize=(30,10))
for i in range(5):
    axes[i].imshow(images_dbn[i].reshape(28,28,1), cmap='gray')
plt.savefig("dbn_mnist_images.png")
